# %% [markdown]
# <img src="../files/misc/logo.png" width=300/>
# <h1 style="color:#872325"> Webscrapping </h1>

# %% [markdown]
# De acuerdo a [Wikipedia](https://es.wikipedia.org/wiki/Web_scraping), *Web Scrapping*,
#
# > es una técnica utilizada mediante programas de software para extraer información de sitios web. Usualmente, estos programas simulan la navegación de un humano en la World Wide Web ya sea utilizando el protocolo HTTP manualmente, o incrustando un navegador en una aplicación.
#
# Para fines prácticos, realizamos un web scrapping cuándo no contamos con alguna manera de acceder a información estructurada de datos por analizar (.csv, .json, base de datos, API).

# %% [markdown]
# ---
#
# ## HTML
# Al hacer webscrapping, dependemos de la estructura de la página web para poder acceder a la información que deseamos obtener. La estructura de la página web se define mediante un lenguaje llamado `HTML` (Hypertext Markup Language) el cual se compone por medio de *tags*.
#
# ```HTML
# <tag>
# </tag>
# ```
#
# Un *tag* define una sección de la página. Cada *tag* tiene una propiedad. Un conjunto de estos tags definen el cuerpo de la página.
#
#
# ### Una primera página web
# ```HTML
# <!DOCTYPE html>
# <html>
# <body>
#
# <h1>Data Science and Machine Learning</h1>
#
# </body>
# </html>
# ```
#
# Para nuestros fines, un *tag* representará una sección dentro de la página la cuál nos gustaría explorar o extraer.

# %% [markdown]
# ---
#
# ## CSS
#
# Un *Cascading Style Sheet* (CSS), es un archivo que viene acompañado de un html y define el estilo de la página.
#
# ```CSS
# selector {
#     property: property-value;
# }
# ```
#
# Cada *selector* contiene diferentes [propiedades](http://web.simmons.edu/~grabiner/comm244/weekthree/css-basic-properties.html) de acuerdo al *tag*, clase o *id* que le corresponda.
#
# Para fines de webscrapping, un los *tags*, *ids* y *clases* ofrencen estrucura dentro de una página.
#
# * Tags: estructura general
# * Clase: secciones genéricas dentro de una página
# * *id*: Secciones especifícas

# %% [markdown]
# ---
#
# ## Javascript y el DOM
#
# La mayoría de las páginas que visitamos hoy en día son interactivas. La interactividad de un una página web es proporcionada por un lenguaje de programación llamado `javascript`.
#
# La manera en la que Javascript asigna u obtiene elementos de una página se conoce como el *Document Object Notation* (DOM).
#
# Para fines de webscrapping, esto es importante puesto que en ocasiones, una página es vacía hasta que un programa de Javascript se ejecuta para arrojar información.

# %% [markdown]
# ## Un primer webscrap
#
# En este módulo estaremos ocupando la librería [requests_html](https://github.com/psf/requests-html) para hacer webscrapping.

# %%
from requests_html import HTML

# %%
with open("../files/lec04/ex03.html") as f:
    webp = f.read()

html = HTML(html=webp)
print(html.html)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <link href="style2.css" rel="stylesheet"/>
# </head>
#
# <body>
#
#     <h1>Data Science and Machine Learning</h1>
#
#     <div class="my_class">
#         <p> By <a href="https://bit.ly/34EdyH2">Analysic Nabla</a></p>
#         <p> At the <a href="https://bit.ly/2qDvao4">ITAM</a></p>
#     </div>
#
# </body>
# </html>

# %%
# Extrayendo todos los links de la página
html.links
# Out:
# {'https://bit.ly/2qDvao4', 'https://bit.ly/34EdyH2'}

# %%
# Extrayendo el primer encabezado de la página
html.find("H1", first=True).text
# Out:
# 'Data Science and Machine Learning'

# %%
# Buscando todos los elementos <p> (paragrapshs)
html.find("p")
# Out:
# [<Element 'p' >, <Element 'p' >]

# %%
# Extrayendo una sección dentro de un div
html.find("div", first=True)
# Out:
# <Element 'div' class=('my_class',)>

# %% [markdown]
# ### Un segundo ejemplo

# %%
with open("../files/lec04/ex04.html") as f:
    webp = f.read()

html = HTML(html=webp)
print(html.html)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <link href="style2.css" rel="stylesheet"/>
#     <script>
#         function sendGreeting() {
#             document.getElementById("greeting").innerHTML = "Aprendamos a hacer webscrapping!"
#         }
#
#
#     </script>
# </head>
#
# <body onload="sendGreeting()">
#     <h1>Data Science and Machine Learning</h1>
#
#     <div class="my_class">
#         <p>Por Analysic Nabla</p>
#         <p>En el ITAM</p>
#         <p id="greeting"></p>
#     </div>
#
# </body>
# </html>

# %%
# ¿Qué notamos en este ejemplo que no concuerde
# con lo que esperaríamos ver en la página?
for item in html.find("p"):
    print(item.text)
# Out:
# Por Analysic Nabla
# En el ITAM

# %%
html.find("p[id='greeting']", first=True)
# Out:
# <Element 'p' id='greeting'>

# %% [markdown]
# <h1 style="color:#872325">HTTP Requests</h1>
#
# Las páginas que visitamos día a día viven en un servidor y no en nuestra computadora. Al abrir nuestro navegador y entrar a una página, el navegador solicita la información de la página al servidor por medio de un proceso de intercambio de información conocido como HTTP.
#
# > *Hypertext Transfer Protocol* (HTTP) es un proceso mediante el cual se hace un intercambio de información entre un cliente (un navegador) y un servidor por medio de mensajes.
#
# ![server](https://mdn.mozillademos.org/files/13677/Fetching_a_page.png)
# **Fuente**x: https://developer.mozilla.org

# %% [markdown]
# Dependiendo del tipo de mensaje que le mandemos a un servidor, este procesará la información enviada desde el cliente (nosotros) de diferentes maneras. Para fines de webscrapping, los métodos más comúnes de comunicarte con un servidor son:
#
# * `GET`: Solicitia un archivo determinado al servidor. Un *GET Request* se debe usar exclusivamente para adquirir información.
#     * Obtener información de una página web
#     * Cargar una imágen
#
# * `POST`: Envía datos al servidor para ser procesados
#     * Dejar tu número celular en una página
#     * Loggearte
#     * Dejar un comentario en un blog post

# %% [markdown]
# En Python, podemos hacer conexiones a una página por medio de la librería `requests`

# %%
import requests

# %%
r = requests.get("https://nabla.mx")
r
# Out:
# <Response [200]>

# %% [markdown]
# Posteriormente tendríamos que pasarlo a una instancia de la clase `HTML` para poder analizar la página. Para evitar esto, podemos hacer uso de la clase `HTMLSession` que nos permite hacer llamadas al servidor y acceso al html que nos regrese.

# %%
from requests_html import HTMLSession

# %%
with HTMLSession() as sess:
    r = sess.get("https://nabla.mx")
r
# Out:
# <Response [200]>

# %%
r.html.links
# Out:
# {'https://analysic-nabla.github.io/',
#  'https://melectrico.nabla.mx/',
#  'https://twitter.com/AnalysicNabla',
#  'https://www.facebook.com/Analysic-Nabla-326424374613601/',
#  'https://www.instagram.com/analysicnabla/?hl=es-la',
#  'https://www.linkedin.com/company/analysic-nabla/',
#  'https://www.nabla.mx',
#  'https://www.nabla.mx/acerca-de',
#  'https://www.nabla.mx/contacto',
#  'https://www.nabla.mx/novedades',
#  'https://www.nabla.mx/proyectos',
#  'https://www.nabla.mx/servicios'}

# %% [markdown]
# <h1 style="color:#872325">Webscrapping</h1>

# %% [markdown]
# <h2 style="color:teal">Ejemplo: Arxiv ML Papers (I)</h2>
#
# Consigue el nombre y el link de los último 25 papers en Machine Learning publicados en Arxiv y guárdalos dentro de un archivo `csv`.

# %%
from requests_html import HTMLSession
import pandas as pd

# %%
url = "https://arxiv.org/list/stat.ML/recent"
with HTMLSession() as sess:
    r = sess.get(url)
r
# Out:
# <Response [200]>

# %%
divpage = r.html.find("div[id='dlpage']", first=True)

# %%
divpage.find("h1", first=True).text
# Out:
# 'Machine Learning'

# %%
papers_links = divpage.find("dt")
len(papers_links)
# Out:
# 25

# %%
papers_titles = divpage.find("dd")
len(papers_titles)
# Out:
# 25

# %%
values = []
for link_secc, title_secc in zip(papers_links, papers_titles):
    title = title_secc.find("div[class='list-title mathjax']", first=True).text
    
    abstract_url = link_secc.find("a[title='Abstract']", first=True).absolute_links
    abstract_url, *_ = abstract_url
    
    values.append([title, abstract_url])

# %%
df_values = pd.DataFrame(values, columns=["title", "url"])
df_values.head()
# Out:
#                                                title  \
# 0  Title: Fair Data Adaptation with Quantile Pres...
# 1  Title: Imputing missing values with unsupervis...
# 2  Title: Likelihood Assignment for Out-of-Distri...
# 3  Title: Solving Inverse Problems by Joint Poste...
# 4  Title: TinyCNN: A Tiny Modular CNN Accelerator...
#
#                                 url
# 0  https://arxiv.org/abs/1911.06685
# 1  https://arxiv.org/abs/1911.06646
# 2  https://arxiv.org/abs/1911.06515
# 3  https://arxiv.org/abs/1911.06379
# 4  https://arxiv.org/abs/1911.06777

# %%
# Depuramos la información que no necesitamos
df_values = df_values.assign(title=df_values.title.str.lstrip("Title: "))
df_values.head()
# Out:
#                                                title  \
# 0    Fair Data Adaptation with Quantile Preservation
# 1  Imputing missing values with unsupervised rand...
# 2  Likelihood Assignment for Out-of-Distribution ...
# 3  Solving Inverse Problems by Joint Posterior Ma...
# 4  nyCNN: A Tiny Modular CNN Accelerator for Embe...
#
#                                 url
# 0  https://arxiv.org/abs/1911.06685
# 1  https://arxiv.org/abs/1911.06646
# 2  https://arxiv.org/abs/1911.06515
# 3  https://arxiv.org/abs/1911.06379
# 4  https://arxiv.org/abs/1911.06777

# %%
# df_values.to_csv("ML-arxiv.csv", index=False)

# %% [markdown]
# ## Queries al sistema
#
# En ocasiones un *GET method* puede venir acompañado con parámetros obligatorios u opcionales para el sistema.
#
# * Se denota una sección de parámetros de consulta por medio de `?`.
# * cada par parametro-valor se denota `param=val`
# * se separa cada query por medio de `&`
#
# ```
# http://some-page.com?key1=val1&key2=val2&..&keyn=valn
# ```

# %%
url = "https://arxiv.org/list/stat.ML/recent?show=250"
with HTMLSession() as sess:
    r = sess.get(url)
r
# Out:
# <Response [200]>

# %%
papers_titles = r.html.find("div[id='dlpage']", first=True).find("dd")
len(papers_titles)
# Out:
# 250

# %% [markdown]
# ### Una manera más limpia de mandar queries

# %%
url = "https://arxiv.org/list/stat.ML/recent"
data = {
    "show": 250
}
with HTMLSession() as sess:
    r = sess.get(url, params=data)
r
# Out:
# <Response [200]>

# %%
papers_titles = r.html.find("div[id='dlpage']", first=True).find("dd")
len(papers_titles)
# Out:
# 250

# %% [markdown]
# <h1 style="color:#872325">APIs</h1>
#
# En ocasiones no es necesario acceder a un HTML a fin de obtener la información deseada de una página web.
#
# Un API (*Application programming interface*),
# > es un protocolo de comunicación entre un cliente y un servidor diseñado para simplificar la creación aplicaciónes por parte del cliente. [...] Un API está diseñado de tal manera que si el cliente hace una petición al sistema en un formato específico, siempre tendrá el mismo formato de respuesta por parte del servidor, o iniciará una acción definida.

# %% [markdown]
# En esta sección ocuparemos el API de [Alpha Vantage](https://www.alphavantage.co), un proveedor de información histórica y tiempo real de datos de acciones, FX y criptomonedas.

# %% [markdown]
# <h2 style="color:teal">Ejemplo: Alpha Vantage</h2>

# %% [markdown]
# A fin de hacer mejor uso de un API es importante siempre revisar la documentación del API.

# %%
import os
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %config InlineBackend.figure_format = "retina"

# %%
url = "https://www.alphavantage.co"
base_url = "https://www.alphavantage.co/query"
# Cargamos el API Key de Alpha Vantage (es personal)
avkey = os.environ["ALPHA_VANTAGE_KEY"]

# %%
curr_list_url = "https://www.alphavantage.co/physical_currency_list/"
curr_list = pd.read_csv(curr_list_url).set_index("currency name")
curr_list.head()
# Out:
#                               currency code
# currency name
# United Arab Emirates Dirham             AED
# Afghan Afghani                          AFN
# Albanian Lek                            ALL
# Armenian Dram                           AMD
# Netherlands Antillean Guilder           ANG

# %%
from_curr = "United States Dollar"
curr_list.filter([from_curr], axis=0)
# Out:
#                      currency code
# currency name
# United States Dollar           USD

# %%
currencies = ["Mexican Peso", "Euro", "Brazilian Real", "Argentine Peso"]
target_curr = curr_list.filter(currencies, axis=0)
target_curr
# Out:
#                currency code
# currency name
# Mexican Peso             MXN
# Euro                     EUR
# Brazilian Real           BRL
# Argentine Peso           ARS

# %% [markdown]
# ## Mensajes de Error

# %% [markdown]
# Entramos a la páginas de AlphaVantage y revisamos la documentación para descargar información

# %%
intraday1 = {
    "function": "FX_INTRADAY",
    "to_currency": target_curr["currency code"].values[0],
    "from_currency": "USD",
    "apikey": avkey
}

r = requests.get(base_url, params=intraday1)
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# {'Error Message': 'Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for FX_INTRADAY.'}

# %%
intraday2 = {
    "function": "FX_INTRADAY",
    "to_symbol": target_curr["currency code"].values[0],
    "from_symbol": "USD",
    "apikey": avkey,
    "interval": "1min"
}

r = requests.get(base_url, params=intraday2)
r
# Out:
# <Response [200]>

# %% [markdown]
# ## Manipulando Información de Respuesta
#
# Una vez obtenida la información del API, el siguiente paso es manipular la información para poder analizarla. De ser una seríe de tiempo, lo más natural sería manipularla usando un pandas DataFrame.

# %%
data = r.json()
data.keys()
# Out:
# dict_keys(['Meta Data', 'Time Series FX (1min)'])

# %%
data["Meta Data"]
# Out:
# {'1. Information': 'FX Intraday (1min) Time Series',
#  '2. From Symbol': 'USD',
#  '3. To Symbol': 'MXN',
#  '4. Last Refreshed': '2019-11-18 21:10:00',
#  '5. Interval': '1min',
#  '6. Output Size': 'Compact',
#  '7. Time Zone': 'UTC'}

# %%
df_data = pd.DataFrame(data["Time Series FX (1min)"]).T
df_data.head()
# Out:
#                      1. open  2. high   3. low 4. close
# 2019-11-18 21:10:00  19.2968  19.2974  19.2930  19.2973
# 2019-11-18 21:09:00  19.2946  19.2970  19.2904  19.2944
# 2019-11-18 21:08:00  19.2900  19.3006  19.2700  19.2935
# 2019-11-18 21:07:00  19.2934  19.3052  19.2700  19.2919
# 2019-11-18 21:06:00  19.2965  19.3001  19.2700  19.2965

# %%
df_data.dtypes
# Out:
# 1. open     object
# 2. high     object
# 3. low      object
# 4. close    object
# dtype: object

# %% [markdown]
# ## FX Daily

# %%
intraday1 = {
    "function": "FX_DAILY",
    "to_symbol": target_curr["currency code"].values[0],
    "from_symbol": "USD",
    "apikey": avkey,
    "outputsize": "full",
}

r = requests.get(base_url, params=intraday1)
r
# Out:
# <Response [200]>

# %%
data = r.json()

# %%
df_data = pd.DataFrame(data["Time Series FX (Daily)"], dtype=float).T.sort_index()

# %%
(df_data.apply(lambda x: x["4. close"] - x["1. open"], axis=1)
        .plot(figsize=(12, 4), linewidth=1))
plt.xticks(rotation=90)
plt.grid(alpha=0.4)

# %% [markdown]
# <h1 style="color:#872325">API Wrappers (Liberías)</h1>
#
# Como hemos visto, utilizar un API require la codificación de los parámetros que espera recibir el servidor, hacer la llamada al servidor para validar la respuesta y manipular la información recibida a fin de hacer uso de esta.
#
# De querer obtener el mismo formato de respuesta sería necesario crear una librería en Python que contemple cada uno de estos pasos, lo cuál se podría volver una tarea tediosa.
#
# Un **API Wrapper** es una librería escrita en un lenguaje de programación que nos da acceso a un API usando un lenguaje de programación específico
#
# **Nota**: Una de las desventajas de usar un API Wrapper son los posibles *bugs* que el wrapper podría tener.

# %% [markdown]
# https://github.com/RomelTorres/alpha_vantage
#
# ```
# pip install alpha_vantage
# ```

# %%
from alpha_vantage.foreignexchange import ForeignExchange

# %%
fx = ForeignExchange(key=avkey, output_format="pandas")
data, metadata = fx.get_currency_exchange_daily("USD", "MXN")
data["4. close"].plot()

# %% [markdown]
# <h2 style="color:crimson">Ejercicios</h2>
#
# 1. Repite el ejemplo *Arxiv ML Papers (I)*, agrega dos nuevas columnas al DataFrame final: `Abstract`, con el resumen de cada paper; `Submitted`, con la fecha en la que fue agregado al sistema. **Hint**: Ambos elementos se encuentran dentro de la *url* encontrada.
#
# ----
#
# 2. Por medio de la librería `requests` y el API de AlphaVantage, consigue los precios históricos de las monedas `["MXN", "EUR", "BRL", "ARS", "CHF"]` respecto al dólar (todos los precios deben estar en dólares). Crea un DataFrame con cada colúmna la moneda de referencia:
#
# <table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>MXN</th>      <th>EUR</th>      <th>BRL</th>      <th>ARS</th>      <th>CHF</th>    </tr>  </thead>  <tbody>    <tr>      <th>2014-11-24</th>      <td>0.0732</td>      <td>1.2438</td>      <td>0.3920</td>      <td>0.1169</td>      <td>1.0342</td>    </tr>    <tr>      <th>2014-11-25</th>      <td>0.0731</td>      <td>1.2473</td>      <td>0.3955</td>      <td>0.1169</td>      <td>1.0370</td>    </tr>    <tr>      <th>2014-11-26</th>      <td>0.0728</td>      <td>1.2507</td>      <td>0.3995</td>      <td>0.1168</td>      <td>1.0401</td>    </tr>    <tr>      <th>2014-11-27</th>      <td>0.0726</td>      <td>1.2458</td>      <td>0.3947</td>      <td>0.1169</td>      <td>1.0363</td>    </tr>    <tr>      <th>2014-11-28</th>      <td>0.0717</td>      <td>1.2451</td>      <td>0.3891</td>      <td>0.1168</td>      <td>1.0351</td>    </tr>  </tbody></table>
#
#
# ----
# 3. Con el DataFrame creado en el ejercicio 2, crea el siguiente mapa de calor con la correlación entre cada una de las monedas. **hint**: Revisa que métodos tiene un DataFrame para crear correlaciones; considera la librería `seaborn`.
#
# ![](../files/lec04/imgs/heatmap.png)
#
# ---
#
# 4. Con el DataFrame creado en el ejercicio 2, crea un nuevo DataFrame que incluya una correlación móvil con ventana de 30 días de cada una de las monedas respecto a `"MXN"`. **hint**: Investiga sobre el método `.xs` de un DataFrame
#
# <table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>EUR</th>      <th>BRL</th>      <th>ARS</th>      <th>CHF</th>    </tr>  </thead>  <tbody>    <tr>      <th>2015-03-19</th>      <td>0.900941</td>      <td>0.870440</td>      <td>0.835029</td>      <td>0.916637</td>    </tr>    <tr>      <th>2015-03-20</th>      <td>0.874866</td>      <td>0.815453</td>      <td>0.762308</td>      <td>0.903594</td>    </tr>    <tr>      <th>2015-03-22</th>      <td>0.866783</td>      <td>0.789977</td>      <td>0.726098</td>      <td>0.900547</td>    </tr>    <tr>      <th>2015-03-23</th>      <td>0.835823</td>      <td>0.728781</td>      <td>0.643129</td>      <td>0.885424</td>    </tr>    <tr>      <th>2015-03-24</th>      <td>0.801267</td>      <td>0.671188</td>      <td>0.560149</td>      <td>0.877682</td>    </tr>  </tbody></table>
#
# ---
#
# 5. Con el DataFrame creado en el ejercicio 4, crea la siguiente figura con _scatterplots_ entre todas las combinaciones de las correlaciones respecto a `"MXN"`. ¿Encuentras algún patrón en alguna combinación?
#
# ![](../files/lec04/imgs/scatter.png)
#
# ---
#
# 6. Con el DataFrame creado en el ejercicio 4, crea la siguiente figura, la cuál representa, a cada observación, la correlación promedio entre todas las monedas respecto a `"MXN"` y unas bandas que representan la correlación máxima y mínima a cada observación.
#
# ![](../files/lec04/imgs/corr_ts.png)

# %% [markdown]
# ## References
#
#
# * https://developer.mozilla.org/en-US/docs/Web
# * https://www.w3schools.com/tags/ref_httpmethods.asp

# %% [markdown]
# 1. Ejercicio 1

# %%
from requests_html import HTMLSession
import pandas as pd
import re

# %%
url = "https://arxiv.org/list/stat.ML/recent"
with HTMLSession() as sess:
    r = sess.get(url)
r
# Out:
# <Response [200]>

# %%
divpage = r.html.find("div[id='dlpage']", first=True)

# %%
divpage.find("h1", first=True).text
# Out:
# 'Machine Learning'

# %%
papers_links = divpage.find("dt")
len(papers_links)
# Out:
# 25

# %%
papers_titles = divpage.find("dd")
len(papers_titles)
# Out:
# 25

# %%
values = []
for link_secc, title_secc in zip(papers_links, papers_titles):
    title = title_secc.find("div[class='list-title mathjax']", first=True).text
    
    abstract_url = link_secc.find("a[title='Abstract']", first=True).absolute_links
    abstract_url, *_ = abstract_url
    
    url = abstract_url
    with HTMLSession() as sess:
        d = sess.get(url)
    
    div_page = d.html.find("div[id='abs']", first=True)
    date = div_page.find("div[class='dateline']", first=True).text
    
    div_abs = d.html.find("blockquote[class='abstract mathjax']", first = True)
    a = div_abs.find("blockquote[class='abstract mathjax']", first=True).text

    abstract, *_ = re.findall("(?<=Abstract\: ).*"  , a)
    
    values.append([title, abstract_url, date, abstract])

# %%
df_values = pd.DataFrame(values, columns=["title", "url", "date","abstract"])
df_values.head()
# Out:
#                                                title  \
# 0     Title: Self-Tuning Deep Reinforcement Learning
# 1  Title: The estimation error of general first o...
# 2  Title: Generalizing Convolutional Neural Netwo...
# 3  Title: A Deep Generative Model for Fragment-Ba...
# 4  Title: Risk Bounds for Multi-layer Perceptrons...
#
#                                 url                        date  \
# 0  https://arxiv.org/abs/2002.12928  (Submitted on 28 Feb 2020)
# 1  https://arxiv.org/abs/2002.12903  (Submitted on 28 Feb 2020)
# 2  https://arxiv.org/abs/2002.12880  (Submitted on 25 Feb 2020)
# 3  https://arxiv.org/abs/2002.12826  (Submitted on 28 Feb 2020)
# 4  https://arxiv.org/abs/2002.12640  (Submitted on 28 Feb 2020)
#
#                                             abstract
# 0  Reinforcement learning (RL) algorithms often r...
# 1  Modern large-scale statistical models require ...
# 2  The translation equivariance of convolutional ...
# 3  Molecule generation is a challenging open prob...
# 4  We characterize the behavior of integral opera...

# %%
# Depuramos la información que no necesitamos
df_values = df_values.assign(title=df_values.title.str.lstrip("Title: "))
df_values.head()
# Out:
#                                                title  \
# 0            Self-Tuning Deep Reinforcement Learning
# 1  he estimation error of general first order met...
# 2  Generalizing Convolutional Neural Networks for...
# 3  A Deep Generative Model for Fragment-Based Mol...
# 4  Risk Bounds for Multi-layer Perceptrons throug...
#
#                                 url                        date  \
# 0  https://arxiv.org/abs/2002.12928  (Submitted on 28 Feb 2020)
# 1  https://arxiv.org/abs/2002.12903  (Submitted on 28 Feb 2020)
# 2  https://arxiv.org/abs/2002.12880  (Submitted on 25 Feb 2020)
# 3  https://arxiv.org/abs/2002.12826  (Submitted on 28 Feb 2020)
# 4  https://arxiv.org/abs/2002.12640  (Submitted on 28 Feb 2020)
#
#                                             abstract
# 0  Reinforcement learning (RL) algorithms often r...
# 1  Modern large-scale statistical models require ...
# 2  The translation equivariance of convolutional ...
# 3  Molecule generation is a challenging open prob...
# 4  We characterize the behavior of integral opera...

# %%
df_values.tail()
# Out:
#                                                 title  \
# 20  Deep Residual-Dense Lattice Network for Speech...
# 21  Uncovering Insurance Fraud Conspiracy with Net...
# 22  owards Learning a Universal Non-Semantic Repre...
# 23  DIHARD II is Still Hard: Experimental Results ...
# 24  A Novel Decision Tree for Depression Recogniti...
#
#                                  url                        date  \
# 20  https://arxiv.org/abs/2002.12794  (Submitted on 27 Feb 2020)
# 21  https://arxiv.org/abs/2002.12789  (Submitted on 27 Feb 2020)
# 22  https://arxiv.org/abs/2002.12764  (Submitted on 25 Feb 2020)
# 23  https://arxiv.org/abs/2002.12761  (Submitted on 23 Feb 2020)
# 24  https://arxiv.org/abs/2002.12759  (Submitted on 22 Feb 2020)
#
#                                              abstract
# 20  Convolutional neural networks (CNNs) with resi...
# 21  Fraudulent claim detection is one of the great...
# 22  The ultimate goal of transfer learning is to r...
# 23  In this paper, we present the submitted system...
# 24  Depression is a common mental disorder worldwi...

# %%
url = "https://arxiv.org/abs/2002.12321"
with HTMLSession() as sess:
    d = sess.get(url)
d
# Out:
# <Response [200]>

# %%
div_page = d.html.find("div[id='abs']", first=True)

# %%
div_page.find("div[class='dateline']", first=True).text
# Out:
# '(Submitted on 27 Feb 2020)'

# %%
div_abs = d.html.find("blockquote[class = 'abstract mathjax']", first = True)

# %%
a = div_abs.find("blockquote[class='abstract mathjax']", first=True).text

abstract, *_ = re.findall("(?<=Abstract\: ).*"  , a)

abstract
# Out:
# 'Depression is a common mental disorder worldwide which causes a range of serious outcomes. The diagnosis of depression relies on patient-reported scales and psychiatrist interview which may lead to subjective bias. In recent years, more and more researchers are devoted to depression recognition in speech , which may be an effective and objective indicator. This study proposes a new speech segment fusion method based on decision tree to improve the depression recognition accuracy and conducts a validation on a sample of 52 subjects (23 depressed patients and 29 healthy controls). The recognition accuracy are 75.8% and 68.5% for male and female respectively on gender-dependent models. It can be concluded from the data that the proposed decision tree model can improve the depression classification performance.'

# %% [markdown]
# 2. Por medio de la librería requests y el API de AlphaVantage, consigue los precios históricos de las monedas ["MXN", "EUR", "BRL", "ARS", "CHF"] respecto al dólar (todos los precios deben estar en dólares). Crea un DataFrame con cada colúmna la moneda de referencia:

# %%
import os
import requests
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
from alpha_vantage.foreignexchange import ForeignExchange

# %%
# %config InlineBackend.figure_format = "retina"

# %%
url = "https://www.alphavantage.co"
base_url = "https://www.alphavantage.co/query"
# Cargamos el API Key de Alpha Vantage (es personal)
os.environ["ALPHA_VANTAGE_KEY"] = "UJO477TRH6L6ELHO"
avkey = os.environ["ALPHA_VANTAGE_KEY"]

# %%
curr_list_url = "https://www.alphavantage.co/physical_currency_list/"
curr_list = pd.read_csv(curr_list_url).set_index("currency name")
curr_list.head()
# Out:
#                               currency code
# currency name
# United Arab Emirates Dirham             AED
# Afghan Afghani                          AFN
# Albanian Lek                            ALL
# Armenian Dram                           AMD
# Netherlands Antillean Guilder           ANG

# %%
currencies = ["Mexican Peso", "Euro", "Brazilian Real", "Argentine Peso","Swiss Franc"]
target_curr = curr_list.filter(currencies, axis=0)
target_curr
# Out:
#                currency code
# currency name
# Mexican Peso             MXN
# Euro                     EUR
# Brazilian Real           BRL
# Argentine Peso           ARS
# Swiss Franc              CHF

# %%
intraday1 = {
    "function": "FX_DAILY",
    "to_symbol":"USD" ,
    "from_symbol": target_curr["currency code"].values[0],
    "apikey": "UJO477TRH6L6ELHO",
    "outputsize": "full",
}

r = requests.get(base_url, params=intraday1)
r
# Out:
# <Response [200]>

# %%
data = r.json()
data['Time Series FX (Daily)'].items()
# Out:
# dict_items([('2020-03-02', {'1. open': '0.0504', '2. high': '0.0511', '3. low': '0.0503', '4. close': '0.0508'}), ('2020-03-01', {'1. open': '0.0509', '2. high': '0.0509', '3. low': '0.0502', '4. close': '0.0503'}), ('2020-02-29', {'1. open': '0.0510', '2. high': '0.0510', '3. low': '0.0510', '4. close': '0.0510'}), ('2020-02-28', {'1. open': '0.0513', '2. high': '0.0514', '3. low': '0.0502', '4. close': '0.0510'}), ('2020-02-27', {'1. open': '0.0518', '2. high': '0.0519', '3. low': '0.0512', '4. close': '0.0512'}), ('2020-02-26', {'1. open': '0.0524', '2. high': '0.0524', '3. low': '0.0517', '4. close': '0.0518'}), ('2020-02-25', {'1. open': '0.0524', '2. high': '0.0528', '3. low': '0.0520', '4. close': '0.0523'}), ('2020-02-24', {'1. open': '0.0527', '2. high': '0.0527', '3. low': '0.0518', '4. close': '0.0524'}), ('2020-02-23', {'1. open': '0.0529', '2. high': '0.0532', '3. low': '0.0526', '4. close': '0.0526'}), ('2020-02-22', {'1. open': '0.0529', '2. high': '0.0529', '3. low': '0.0529', '4. close': '0.0529'}), ('2020-02-21', {'1. open': '0.0530', '2. high': '0.0532', '3. low': '0.0524', '4. close': '0.0529'}), ('2020-02-20', {'1. open': '0.0538', '2. high': '0.0539', '3. low': '0.0530', '4. close': '0.0530'}), ('2020-02-19', {'1. open': '0.0537', '2. high': '0.0539', '3. low': '0.0536', '4. close': '0.0538'}), ('2020-02-18', {'1. open': '0.0538', '2. high': '0.0539', '3. low': '0.0535', '4. close': '0.0538'}), ('2020-02-17', {'1. open': '0.0539', '2. high': '0.0540', '3. low': '0.0537', '4. close': '0.0539'}), ('2020-02-16', {'1. open': '0.0539', '2. high': '0.0540', '3. low': '0.0537', '4. close': '0.0539'}), ('2020-02-15', {'1. open': '0.0539', '2. high': '0.0539', '3. low': '0.0539', '4. close': '0.0539'}), ('2020-02-14', {'1. open': '0.0537', '2. high': '0.0539', '3. low': '0.0537', '4. close': '0.0539'}), ('2020-02-13', {'1. open': '0.0537', '2. high': '0.0538', '3. low': '0.0535', '4. close': '0.0537'}), ('2020-02-12', {'1. open': '0.0535', '2. high': '0.0537', '3. low': '0.0535', '4. close': '0.0536'}), ('2020-02-11', {'1. open': '0.0534', '2. high': '0.0536', '3. low': '0.0534', '4. close': '0.0536'}), ('2020-02-10', {'1. open': '0.0532', '2. high': '0.0535', '3. low': '0.0531', '4. close': '0.0534'}), ('2020-02-09', {'1. open': '0.0532', '2. high': '0.0532', '3. low': '0.0532', '4. close': '0.0532'}), ('2020-02-08', {'1. open': '0.0532', '2. high': '0.0532', '3. low': '0.0532', '4. close': '0.0532'}), ('2020-02-07', {'1. open': '0.0535', '2. high': '0.0537', '3. low': '0.0531', '4. close': '0.0532'}), ('2020-02-06', {'1. open': '0.0537', '2. high': '0.0539', '3. low': '0.0534', '4. close': '0.0536'}), ('2020-02-05', {'1. open': '0.0535', '2. high': '0.0538', '3. low': '0.0534', '4. close': '0.0537'}), ('2020-02-04', {'1. open': '0.0531', '2. high': '0.0536', '3. low': '0.0530', '4. close': '0.0536'}), ('2020-02-03', {'1. open': '0.0529', '2. high': '0.0534', '3. low': '0.0529', '4. close': '0.0531'}), ('2020-02-02', {'1. open': '0.0529', '2. high': '0.0530', '3. low': '0.0529', '4. close': '0.0529'}), ('2020-02-01', {'1. open': '0.0530', '2. high': '0.0530', '3. low': '0.0530', '4. close': '0.0530'}), ('2020-01-31', {'1. open': '0.0532', '2. high': '0.0533', '3. low': '0.0528', '4. close': '0.0530'}), ('2020-01-30', {'1. open': '0.0534', '2. high': '0.0535', '3. low': '0.0529', '4. close': '0.0532'}), ('2020-01-29', {'1. open': '0.0534', '2. high': '0.0536', '3. low': '0.0532', '4. close': '0.0534'}), ('2020-01-28', {'1. open': '0.0528', '2. high': '0.0534', '3. low': '0.0528', '4. close': '0.0534'}), ('2020-01-27', {'1. open': '0.0530', '2. high': '0.0531', '3. low': '0.0527', '4. close': '0.0529'}), ('2020-01-26', {'1. open': '0.0531', '2. high': '0.0531', '3. low': '0.0530', '4. close': '0.0531'}), ('2020-01-24', {'1. open': '0.0532', '2. high': '0.0534', '3. low': '0.0529', '4. close': '0.0533'}), ('2020-01-23', {'1. open': '0.0535', '2. high': '0.0535', '3. low': '0.0530', '4. close': '0.0533'}), ('2020-01- ...

# %%
df_data = pd.DataFrame(data["Time Series FX (Daily)"], dtype=float).T.sort_index()

# %%
df_data["4. close"]
# Out:
# 2014-11-07    0.0737
# 2014-11-09    0.0738
# 2014-11-10    0.0734
# 2014-11-11    0.0735
# 2014-11-12    0.0737
# 2014-11-13    0.0735
# 2014-11-14    0.0739
# 2014-11-15    0.0739
# 2014-11-16    0.0738
# 2014-11-17    0.0735
# 2014-11-18    0.0737
# 2014-11-19    0.0733
# 2014-11-20    0.0732
# 2014-11-21    0.0733
# 2014-11-22    0.0734
# 2014-11-23    0.0733
# 2014-11-24    0.0732
# 2014-11-25    0.0731
# 2014-11-26    0.0728
# 2014-11-27    0.0726
# 2014-11-28    0.0717
# 2014-11-29    0.0717
# 2014-11-30    0.0717
# 2014-12-01    0.0715
# 2014-12-02    0.0708
# 2014-12-03    0.0709
# 2014-12-04    0.0706
# 2014-12-05    0.0696
# 2014-12-06    0.0696
# 2014-12-07    0.0696
#                ...
# 2020-02-02    0.0529
# 2020-02-03    0.0531
# 2020-02-04    0.0536
# 2020-02-05    0.0537
# 2020-02-06    0.0536
# 2020-02-07    0.0532
# 2020-02-08    0.0532
# 2020-02-09    0.0532
# 2020-02-10    0.0534
# 2020-02-11    0.0536
# 2020-02-12    0.0536
# 2020-02-13    0.0537
# 2020-02-14    0.0539
# 2020-02-15    0.0539
# 2020-02-16    0.0539
# 2020-02-17    0.0539
# 2020-02-18    0.0538
# 2020-02-19    0.0538
# 2020-02-20    0.0530
# 2020-02-21    0.0529
# 2020-02-22    0.0529
# 2020-02-23    0.0526
# 2020-02-24    0.0524
# 2020-02-25    0.0523
# 2020-02-26    0.0518
# 2020-02-27    0.0512
# 2020-02-28    0.0510
# 2020-02-29    0.0510
# 2020-03-01    0.0503
# 2020-03-02    0.0510
# Name: 4. close, Length: 1787, dtype: float64

# %%
currencies = list(target_curr["currency code"])

# %%
def div_ext (avkey, currency , base_url):
    daily = {
        "function": "FX_DAILY",
        "to_symbol": "USD",
        "from_symbol": currency,
        "apikey": avkey,
        "outputsize": "full",
        }
    r = requests.get(base_url, params=daily) 
    data = r.json()
    
    p = defaultdict(dict)
    for key, values in data['Time Series FX (Daily)'].items():
        p[key] = values['4. close']
    return p

# %%
currency_FX = defaultdict(dict)
for currency  in currencies:
    data = div_ext(avkey, currency, base_url)
    currency_FX[currency] = data

# %%
df_data_curr = pd.DataFrame(currency_FX, dtype=float).dropna().sort_index()

# %%
df_data_curr.head()
# Out:
#                MXN     EUR     BRL    ARS     CHF
# 2014-11-07  0.0737  1.2454  0.3902  0.117  1.0341
# 2014-11-09  0.0738  1.2462  0.3894  0.117  1.0359
# 2014-11-10  0.0734  1.2424  0.3933  0.117  1.0328
# 2014-11-11  0.0735  1.2473  0.3894  0.117  1.0364
# 2014-11-12  0.0737  1.2428  0.3890  0.117  1.0337

# %% [markdown]
# 3. Con el DataFrame creado en el ejercicio 2, crea el siguiente mapa de calor con la correlación entre cada una de las monedas. hint: Revisa que métodos tiene un DataFrame para crear correlaciones; considera la librería seaborn.

# %%
import seaborn as sns

# %%
headmap_sns = sns.heatmap(df_data_curr.corr(), annot=True)

# %% [markdown]
# 4. Con el DataFrame creado en el ejercicio 2, crea un nuevo DataFrame que incluya una correlación móvil con ventana de 30 días de cada una de las monedas respecto a "MXN". hint: Investiga sobre el método .xs de un DataFrame

# %%
new  = df_data_curr.rolling(30).corr().dropna()

# %%
new_data = new.xs("MXN", level = 1)[["EUR","BRL","ARS","CHF"]]

# %%
new_data.loc["2015-03-19":]
# Out:
#                  EUR       BRL       ARS       CHF
# 2015-03-19  0.900941  0.870440  0.835029  0.916637
# 2015-03-20  0.874866  0.815453  0.762308  0.903594
# 2015-03-22  0.866783  0.789977  0.726098  0.900547
# 2015-03-23  0.835823  0.728781  0.643129  0.885424
# 2015-03-24  0.801267  0.671188  0.560149  0.877682
# 2015-03-25  0.791776  0.623792  0.512389  0.876820
# 2015-03-26  0.793666  0.607022  0.484317  0.885471
# 2015-03-27  0.798728  0.594309  0.460264  0.884847
# 2015-03-29  0.815587  0.587980  0.447217  0.884267
# 2015-03-30  0.799986  0.566583  0.434327  0.849757
# 2015-03-31  0.789080  0.533743  0.389750  0.837129
# 2015-04-01  0.768276  0.496501  0.313735  0.829676
# 2015-04-02  0.742357  0.440164  0.187739  0.825463
# 2015-04-03  0.715688  0.364760 -0.022770  0.825986
# 2015-04-05  0.704246  0.285472 -0.205002  0.827052
# 2015-04-06  0.701898  0.241091 -0.350750  0.828519
# 2015-04-07  0.672482  0.183204 -0.502447  0.820551
# 2015-04-08  0.643728  0.202643 -0.636153  0.814085
# 2015-04-09  0.641895  0.235220 -0.683079  0.811215
# 2015-04-10  0.673861  0.317792 -0.607512  0.818487
# 2015-04-12  0.705404  0.396179 -0.547107  0.823620
# 2015-04-13  0.770064  0.406520 -0.398262  0.818281
# 2015-04-14  0.797042  0.473598 -0.254194  0.805794
# 2015-04-15  0.783762  0.454193 -0.171385  0.770546
# 2015-04-16  0.775641  0.424154 -0.101336  0.735579
# 2015-04-17  0.734083  0.312368  0.039308  0.630814
# 2015-04-19  0.665860  0.184174  0.219626  0.470344
# 2015-04-20  0.627724  0.028106  0.328890  0.319204
# 2015-04-21  0.599842 -0.106932  0.464378  0.156789
# 2015-04-22  0.610917 -0.194172  0.530950  0.158749
# ...              ...       ...       ...       ...
# 2020-01-29 -0.545066 -0.720426 -0.246153  0.348096
# 2020-01-30 -0.580377 -0.691300 -0.173405  0.244717
# 2020-01-31 -0.559067 -0.590575 -0.119866  0.153511
# 2020-02-02 -0.521581 -0.470924 -0.045619  0.032406
# 2020-02-03 -0.467235 -0.397241 -0.029617  0.033687
# 2020-02-04 -0.459369 -0.408057 -0.208701  0.052101
# 2020-02-05 -0.488497 -0.398415 -0.274027 -0.025611
# 2020-02-06 -0.524563 -0.425109 -0.360624 -0.123292
# 2020-02-07 -0.425552 -0.334457 -0.324880 -0.178355
# 2020-02-09 -0.325771 -0.229865 -0.289013 -0.196466
# 2020-02-10 -0.326094 -0.230085 -0.292757 -0.219110
# 2020-02-11 -0.346474 -0.217440 -0.315599 -0.288326
# 2020-02-12 -0.402071 -0.250076 -0.371034 -0.374712
# 2020-02-13 -0.466269 -0.267561 -0.446735 -0.478008
# 2020-02-14 -0.555227 -0.299891 -0.539930 -0.578555
# 2020-02-15 -0.613109 -0.322517 -0.602830 -0.651583
# 2020-02-16 -0.642213 -0.321493 -0.639529 -0.697885
# 2020-02-17 -0.670361 -0.347440 -0.668854 -0.717457
# 2020-02-18 -0.687420 -0.372543 -0.682816 -0.732140
# 2020-02-19 -0.698773 -0.395383 -0.692332 -0.741335
# 2020-02-20 -0.574887 -0.293336 -0.550159 -0.621497
# 2020-02-21 -0.501223 -0.198255 -0.419549 -0.571101
# 2020-02-23 -0.382933 -0.073669 -0.259826 -0.475842
# 2020-02-24 -0.253191  0.069805 -0.088478 -0.361362
# 2020-02-25 -0.209582  0.152762  0.018184 -0.341759
# 2020-02-26 -0.132666  0.332192  0.146621 -0.273137
# 2020-02-27 -0.196531  0.504148  0.304529 -0.355744
# 2020-02-28 -0.268271  0.627480  0.426425 -0.451384
# 2020-03-01 -0.340049  0.718202  0.533992 -0.538785
# 2020-03-02 -0.413025  0.773674  0.578212 -0.596836
#
# [1540 rows x 4 columns]

# %% [markdown]
# 5. Con el DataFrame creado en el ejercicio 4, crea la siguiente figura con scatterplots entre todas las combinaciones de las correlaciones respecto a "MXN". ¿Encuentras algún patrón en alguna combinación?

# %%
sns.pairplot(new_data, vars = ["EUR","BRL","ARS","CHF"])

# %% [markdown]
# 6. Con el DataFrame creado en el ejercicio 4, crea la siguiente figura, la cuál representa, a cada observación, la correlación promedio entre todas las monedas respecto a "MXN" y unas bandas que representan la correlación máxima y mínima a cada observación.

# %%
new_data['max_corr'] =new_data[['EUR', 'BRL', 'ARS', 'CHF']].max(axis = 1) 
new_data['min_corr'] =new_data[['EUR', 'BRL', 'ARS', 'CHF']].min(axis = 1) 
new_data['avg_corr'] =new_data[['EUR', 'BRL', 'ARS', 'CHF']].mean(axis = 1)

# %%
data_plot = new_data[["max_corr","avg_corr","min_corr"]]

# %%
sns.set(rc={'figure.figsize':(12,6)})
fig, ax = plt.subplots()
ax.xaxis.set_major_locator(plt.MaxNLocator(10))
ax.tick_params(axis = "x",labelrotation=90)
ax.plot(data_plot['avg_corr'])
ax.fill_between(data_plot.index ,data_plot['min_corr'] , data_plot['max_corr'], color = "grey", alpha = 0.5)
